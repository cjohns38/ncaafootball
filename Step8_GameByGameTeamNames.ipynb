# %%
import scrapy, os
import pandas as pd
from scrapy.crawler import CrawlerProcess
from scrapy.exporters import CsvItemExporter
from scrapy.linkextractors import LinkExtractor
from scrapy.item import DictItem, Field

# %%
def create_item_class(class_name,field_list):
    field_dict = {}
    for field_name in field_list:
        field_dict[field_name] = Field()

    return type(class_name, (DictItem,), {'fields':field_dict})

# %%
class Pipeline(object):
    """Scrapy Pipeline Object for Links, Results, Team, Individual"""
    
    def __init__(self):
        self.files = {}
        self.exporters = {}
    
    def create_file(self, file, _dir): 
        # if the file doesn't exist create it 
        if file not in self.files:
            self.files[file] = open(os.path.join(_dir, file + '.csv'), 'wb')
            self.exporters[file] = CsvItemExporter(self.files[file])
            self.exporters[file].start_exporting()
    
    def close_spider(self, spider):
        [e.finish_exporting() for e in self.exporters.values()]
        [f.close() for f in self.files.values()]
 
    def process_item(self, item, spider):
        # Define what item type it is 
        file = type(item).__name__.replace("item_", "").lower()
        if "link" in file: 
            _dir = "Links" 
        else: 
            _dir = "Data"
        
        self.create_file(file, _dir)
        
        # Export 
        self.exporters[file].export_item(item)
        
        return item

# %%
class TeamNameSpider(scrapy.Spider): 
    name = "TeamNameSpider"
    
    def start_requests(self): 
        file_in = 'links_gamebygame.csv'

        # Pull in the data 
        data = pd.read_csv(os.path.join("Links", file_in))
        _list = data.to_dict(orient='record')
        
        # Loop through the links 
        for url in _list[:1]: 
            print(url['link'])
            yield scrapy.Request(url=url['link'], 
                                 callback=self.parse,
                                 meta = {'team':url['team'], 
                                         'year':url['year'],
                                        }
                                )
    
    def parse(self, response): 
        regex = "http\:\/\/stats\.ncaa\.org\/team\/\d+\/\d+"

        # Get all the links on the page
        le = LinkExtractor(allow = regex) 
        links = le.extract_links(response)
        
        # Build up the output 
        for link in links:   
            yield scrapy.Request(url = link.url, 
                                 callback = self.parse_data, 
                                 meta = {'team': link.text,}
                                )
            
            
    def parse_data(self, response): 
        
        teamName = response.xpath('//*[@id="contentarea"]/fieldset/legend/a/text()').extract_first()
        record = {'shortName': response.meta['team'], 
                  'longName':teamName
                 }
        
        # Create dynamic items
        field_list = record.keys()
        DynamicItem = create_item_class('gamebygame_teamNames', field_list)
        item = DynamicItem()
        
        # yield items
        for k, v in record.items(): 
            item[k] = v
        yield item

# %%
process = CrawlerProcess({'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)',
                          'ITEM_PIPELINES': {'__main__.Pipeline':100}
                         })

process.crawl(TeamNameSpider)
process.start()
# Out:
# 2017-12-30 09:54:11 [scrapy.utils.log] INFO: Scrapy 1.4.0 started (bot: scrapybot)
# 2017-12-30 09:54:11 [scrapy.utils.log] INFO: Overridden settings: {'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'}
# 2017-12-30 09:54:11 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2017-12-30 09:54:11 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2017-12-30 09:54:11 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2017-12-30 09:54:11 [scrapy.middleware] INFO: Enabled item pipelines:
# ['__main__.Pipeline']
# 2017-12-30 09:54:11 [scrapy.core.engine] INFO: Spider opened
# 2017-12-30 09:54:11 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2017-12-30 09:54:11 [scrapy.extensions.telnet] DEBUG: Telnet console listening on 127.0.0.1:6024
# http://stats.ncaa.org/player/game_by_game?game_sport_year_ctl_id=12240&org_id=721&stats_player_seq=-100
# 2017-12-30 09:54:17 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://stats.ncaa.org/player/game_by_game?game_sport_year_ctl_id=12240&org_id=721&stats_player_seq=-100> (referer: None)
# 2017-12-30 09:54:18 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (302) to <GET http://stats.ncaa.org/teams/62793> from <GET http://stats.ncaa.org/team/721/11520>
# 2017-12-30 09:54:18 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (302) to <GET http://stats.ncaa.org/teams/19630> from <GET http://stats.ncaa.org/team/107/12240>
# 2017-12-30 09:54:18 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (302) to <GET http://stats.ncaa.org/teams/19729> from <GET http://stats.ncaa.org/team/731/12240>
# 2017-12-30 09:54:18 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (302) to <GET http://stats.ncaa.org/teams/19727> from <GET http://stats.ncaa.org/team/725/12240>
# 2017-12-30 09:54:18 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (302) to <GET http://stats.ncaa.org/teams/19624> from <GET http://stats.ncaa.org/team/66/12240>
# 2017-12-30 09:54:18 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (302) to <GET http://stats.ncaa.org/teams/19683> from <GET http://stats.ncaa.org/team/473/12240>
# 2017-12-30 09:54:18 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (302) to <GET http://stats.ncaa.org/teams/19650> from <GET http://stats.ncaa.org/team/277/12240>
# 2017-12-30 09:54:18 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (302) to <GET http://stats.ncaa.org/teams/19629> from <GET http://stats.ncaa.org/team/96/12240>
# 2017-12-30 09:54:18 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (302) to <GET http://stats.ncaa.org/teams/19636> from <GET http://stats.ncaa.org/team/156/12240>
# 2017-12-30 09:54:18 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (302) to <GET http://stats.ncaa.org/teams/19670> from <GET http://stats.ncaa.org/team/416/12240>
# 2017-12-30 09:54:18 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (302) to <GET http://stats.ncaa.org/teams/19741> from <GET http://stats.ncaa.org/team/811/12240>
# 2017-12-30 09:54:18 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (302) to <GET http://stats.ncaa.org/teams/19728> from <GET http://stats.ncaa.org/team/726/12240>
# 2017-12-30 09:54:18 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (302) to <GET http://stats.ncaa.org/teams/19703> from <GET http://stats.ncaa.org/team/630/12240>
# 2017-12-30 09:54:18 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (302) to <GET http://stats.ncaa.org/teams/19805> from <GET http://stats.ncaa.org/team/446/12240>
# 2017-12-30 09:54:18 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (302) to <GET http://stats.ncaa.org/teams/113638> from <GET http://stats.ncaa.org/team/721/12623>
# 2017-12-30 09:54:18 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (302) to <GET http://stats.ncaa.org/teams/19702> from <GET http://stats.ncaa.org/team/626/12240>
# 2017-12-30 09:54:23 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET http://stats.ncaa.org/teams/19630> (failed 1 times): 500 Internal Server Error
# 2017-12-30 09:54:24 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://stats.ncaa.org/teams/19683> (referer: http://stats.ncaa.org/player/game_by_game?game_sport_year_ctl_id=12240&org_id=721&stats_player_seq=-100)
# 2017-12-30 09:54:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/19683>
# {'longName': 'New Mexico  Lobos', 'shortName': '@ New Mexico  '}
# 2017-12-30 09:54:24 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://stats.ncaa.org/teams/19727> (referer: http://stats.ncaa.org/player/game_by_game?game_sport_year_ctl_id=12240&org_id=721&stats_player_seq=-100)
# 2017-12-30 09:54:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/19727>
# {'longName': 'Army West Point Black Knights', 'shortName': ' Army West Point '}
# 2017-12-30 09:54:24 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://stats.ncaa.org/teams/19650> (referer: http://stats.ncaa.org/player/game_by_game?game_sport_year_ctl_id=12240&org_id=721&stats_player_seq=-100)
# 2017-12-30 09:54:24 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://stats.ncaa.org/teams/62793> (referer: http://stats.ncaa.org/player/game_by_game?game_sport_year_ctl_id=12240&org_id=721&stats_player_seq=-100)
# 2017-12-30 09:54:24 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://stats.ncaa.org/teams/19629> (referer: http://stats.ncaa.org/player/game_by_game?game_sport_year_ctl_id=12240&org_id=721&stats_player_seq=-100)
# 2017-12-30 09:54:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/19650>
# {'longName': 'Hawaii  Rainbow Warriors', 'shortName': '@ Hawaii  '}
# 2017-12-30 09:54:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/62793>
# {'longName': 'Air Force Falcons', 'shortName': 'Air Force '}
# 2017-12-30 09:54:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/19629>
# {'longName': 'Fresno St. Bulldogs', 'shortName': ' Fresno St. '}
# 2017-12-30 09:54:24 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://stats.ncaa.org/teams/19729> (referer: http://stats.ncaa.org/player/game_by_game?game_sport_year_ctl_id=12240&org_id=721&stats_player_seq=-100)
# 2017-12-30 09:54:24 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/19729>
# {'longName': 'Utah St. Aggies', 'shortName': ' Utah St. '}
# 2017-12-30 09:54:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://stats.ncaa.org/teams/19624> (referer: http://stats.ncaa.org/player/game_by_game?game_sport_year_ctl_id=12240&org_id=721&stats_player_seq=-100)
# 2017-12-30 09:54:26 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/19624>
# {'longName': 'Boise St. Broncos', 'shortName': '@ Boise St. '}
# 2017-12-30 09:54:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://stats.ncaa.org/teams/19670> (referer: http://stats.ncaa.org/player/game_by_game?game_sport_year_ctl_id=12240&org_id=721&stats_player_seq=-100)
# 2017-12-30 09:54:28 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/19670>
# {'longName': 'Michigan St. Spartans', 'shortName': '@ Michigan St. '}
# 2017-12-30 09:54:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://stats.ncaa.org/teams/19741> (referer: http://stats.ncaa.org/player/game_by_game?game_sport_year_ctl_id=12240&org_id=721&stats_player_seq=-100)
# 2017-12-30 09:54:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://stats.ncaa.org/teams/19805> (referer: http://stats.ncaa.org/player/game_by_game?game_sport_year_ctl_id=12240&org_id=721&stats_player_seq=-100)
# 2017-12-30 09:54:28 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/19741>
# {'longName': 'Wyoming  Cowboys', 'shortName': ' Wyoming  '}
# 2017-12-30 09:54:28 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/19805>
# {'longName': 'Morgan St. Bears', 'shortName': ' Morgan St. '}
# 2017-12-30 09:54:28 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (302) to <GET http://stats.ncaa.org/teams/66692> from <GET http://stats.ncaa.org/team/721/12424>
# 2017-12-30 09:54:28 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (302) to <GET http://stats.ncaa.org/teams/83664> from <GET http://stats.ncaa.org/team/721/11980>
# 2017-12-30 09:54:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://stats.ncaa.org/teams/19636> (referer: http://stats.ncaa.org/player/game_by_game?game_sport_year_ctl_id=12240&org_id=721&stats_player_seq=-100)
# 2017-12-30 09:54:30 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/19636>
# {'longName': 'Colorado St. Rams', 'shortName': '@ Colorado St. '}
# 2017-12-30 09:54:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://stats.ncaa.org/teams/113638> (referer: http://stats.ncaa.org/player/game_by_game?game_sport_year_ctl_id=12240&org_id=721&stats_player_seq=-100)
# 2017-12-30 09:54:30 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/113638>
# {'longName': 'Air Force Falcons', 'shortName': 'Air Force '}
# 2017-12-30 09:54:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://stats.ncaa.org/teams/19703> (referer: http://stats.ncaa.org/player/game_by_game?game_sport_year_ctl_id=12240&org_id=721&stats_player_seq=-100)
# 2017-12-30 09:54:31 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (302) to <GET http://stats.ncaa.org/teams/19726> from <GET http://stats.ncaa.org/team/721/12240>
# 2017-12-30 09:54:31 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/19703>
# {'longName': 'San Jose St. Spartans', 'shortName': ' San Jose St. '}
# 2017-12-30 09:54:31 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET http://stats.ncaa.org/teams/19630> (failed 2 times): 500 Internal Server Error
# 2017-12-30 09:54:32 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://stats.ncaa.org/teams/66692> (referer: http://stats.ncaa.org/player/game_by_game?game_sport_year_ctl_id=12240&org_id=721&stats_player_seq=-100)
# 2017-12-30 09:54:32 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://stats.ncaa.org/teams/19728> (referer: http://stats.ncaa.org/player/game_by_game?game_sport_year_ctl_id=12240&org_id=721&stats_player_seq=-100)
# 2017-12-30 09:54:32 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/66692>
# {'longName': 'Air Force Falcons', 'shortName': 'Air Force '}
# 2017-12-30 09:54:32 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/19728>
# {'longName': 'Navy Midshipmen', 'shortName': '@ Navy '}
# 2017-12-30 09:54:32 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://stats.ncaa.org/teams/19702> (referer: http://stats.ncaa.org/player/game_by_game?game_sport_year_ctl_id=12240&org_id=721&stats_player_seq=-100)
# 2017-12-30 09:54:32 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/19702>
# {'longName': 'San Diego St. Aztecs', 'shortName': '@ San Diego St. '}
# 2017-12-30 09:54:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://stats.ncaa.org/teams/83664> (referer: http://stats.ncaa.org/player/game_by_game?game_sport_year_ctl_id=12240&org_id=721&stats_player_seq=-100)
# 2017-12-30 09:54:33 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/83664>
# {'longName': 'Air Force Falcons', 'shortName': 'Air Force '}
# 2017-12-30 09:54:34 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://stats.ncaa.org/teams/19726> (referer: http://stats.ncaa.org/player/game_by_game?game_sport_year_ctl_id=12240&org_id=721&stats_player_seq=-100)
# 2017-12-30 09:54:34 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/19726>
# {'longName': 'Air Force Falcons', 'shortName': 'Air Force '}
# 2017-12-30 09:54:35 [scrapy.downloadermiddlewares.retry] DEBUG: Gave up retrying <GET http://stats.ncaa.org/teams/19630> (failed 3 times): 500 Internal Server Error
# 2017-12-30 09:54:35 [scrapy.core.engine] DEBUG: Crawled (500) <GET http://stats.ncaa.org/teams/19630> (referer: http://stats.ncaa.org/player/game_by_game?game_sport_year_ctl_id=12240&org_id=721&stats_player_seq=-100)
# 2017-12-30 09:54:35 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <500 http://stats.ncaa.org/teams/19630>: HTTP status code is not handled or not allowed
# 2017-12-30 09:54:35 [scrapy.core.engine] INFO: Closing spider (finished)
# 2017-12-30 09:54:35 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 24406,
#  'downloader/request_count': 41,
#  'downloader/request_method_count/GET': 41,
#  'downloader/response_bytes': 155617,
#  'downloader/response_count': 41,
#  'downloader/response_status_count/200': 19,
#  'downloader/response_status_count/302': 19,
#  'downloader/response_status_count/500': 3,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2017, 12, 30, 15, 54, 35, 585204),
#  'httperror/response_ignored_count': 1,
#  'httperror/response_ignored_status_count/500': 1,
#  'item_scraped_count': 18,
#  'log_count/DEBUG': 61,
#  'log_count/INFO': 8,
#  'memusage/max': 117432320,
#  'memusage/startup': 117432320,
#  'request_depth_max': 1,
#  'response_received_count': 20,
#  'retry/count': 2,
#  'retry/max_reached': 1,
#  'retry/reason_count/500 Internal Server Error': 2,
#  'scheduler/dequeued': 41,
#  'scheduler/dequeued/memory': 41,
#  'scheduler/enqueued': 41,
#  'scheduler/enqueued/memory': 41,
#  'start_time': datetime.datetime(2017, 12, 30, 15, 54, 11, 928536)}
# 2017-12-30 09:54:35 [scrapy.core.engine] INFO: Spider closed (finished)
