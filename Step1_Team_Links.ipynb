# %%
import scrapy, re, urllib, os
import pandas as pd
from scrapy.crawler import CrawlerProcess
from scrapy.linkextractors import LinkExtractor
from scrapy.exporters import CsvItemExporter

# %%
class item_teamlinks(scrapy.Item):
    """Scrapy Item for Team Links for 2014-2017"""
    Link = scrapy.Field()
    Team = scrapy.Field()
    Year = scrapy.Field()

# %%
class TeamLinksCSVPipeline(object):
    """Scrapy Pipeline Object for Team Links 2014-2017"""
    def __init__(self):
        fileName = "TeamLinks.csv"
        self.file = open(os.path.join("Links", fileName), 'wb')
        self.exporter = CsvItemExporter(self.file, fields_to_export=['Team', 'Year', 'Link'])
        self.exporter.start_exporting()
 
    def close_spider(self, spider):
        self.exporter.finish_exporting()
        self.file.close()
 
    def process_item(self, item, spider):
        self.exporter.export_item(item)
        return item

# %%
class TeamSpider(scrapy.Spider): 
    name = "Team"
    
    # List of years to build up URLs to crawl 
    years = [2014, 2015, 2016, 2017] 
    
    # Build list of URLs and crawl 
    start_urls = ["http://stats.ncaa.org/team/inst_team_list?academic_year={year}&conf_id=-1&division=11&sport_code=MFB".format(year = year)
            for year in years]
    
    def parse(self, response): 
        """Parse the crawled pages"""
        # Extract current year from the returned object
        curr_year = urllib.parse.parse_qs(urllib.parse.urlparse(response.url).query)['academic_year'][0]
        
        # Get all the links on the page
        le = LinkExtractor() 
        links = le.extract_links(response)
        
        # Regex pattern to find just the team links 
        team_url_pattern = "http\:\/\/stats\.ncaa\.org\/team\/\d+\/\d+"
        
        # Extract the links, put into item object, yield item object to pipeline which saves results 
        for link in links: 
            match = re.search(team_url_pattern, link.url)
            if match != None: 
                yield item_teamlinks({'Link':link.url, 'Team':link.text, 'Year':curr_year })

# %%
process = CrawlerProcess({'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)',
                          'ITEM_PIPELINES': {'__main__.TeamLinksCSVPipeline':100}
                         })

process.crawl(TeamSpider)
process.start()
# Out:
# 2017-12-11 10:09:44 [scrapy.utils.log] INFO: Scrapy 1.4.0 started (bot: scrapybot)
# 2017-12-11 10:09:44 [scrapy.utils.log] INFO: Overridden settings: {'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'}
# 2017-12-11 10:09:44 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2017-12-11 10:09:44 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2017-12-11 10:09:44 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2017-12-11 10:09:44 [scrapy.middleware] INFO: Enabled item pipelines:
# ['__main__.TeamLinksCSVPipeline']
# 2017-12-11 10:09:44 [scrapy.core.engine] INFO: Spider opened
# 2017-12-11 10:09:44 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2017-12-11 10:09:44 [scrapy.extensions.telnet] DEBUG: Telnet console listening on 127.0.0.1:6023
# 2017-12-11 10:09:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB> (referer: None)
# 2017-12-11 10:09:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB> (referer: None)
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/721/11520',
#  'Team': 'Air Force',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://stats.ncaa.org/team/inst_team_list?academic_year=2017&conf_id=-1&division=11&sport_code=MFB> (referer: None)
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/5/11520', 'Team': 'Akron', 'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/8/11520',
#  'Team': 'Alabama',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/27/11520',
#  'Team': 'Appalachian St.',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/29/11520',
#  'Team': 'Arizona',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/28/11520',
#  'Team': 'Arizona St.',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/31/11520',
#  'Team': 'Arkansas',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/30/11520',
#  'Team': 'Arkansas St.',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/725/11520',
#  'Team': 'Army West Point',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/37/11520',
#  'Team': 'Auburn',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/77/11520', 'Team': 'BYU', 'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/47/11520',
#  'Team': 'Ball St.',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/51/11520',
#  'Team': 'Baylor',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/66/11520',
#  'Team': 'Boise St.',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/67/11520',
#  'Team': 'Boston College',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/71/11520',
#  'Team': 'Bowling Green',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/86/11520',
#  'Team': 'Buffalo',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/107/11520',
#  'Team': 'California',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/129/11520',
#  'Team': 'Central Mich.',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/140/11520',
#  'Team': 'Cincinnati',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/147/11520',
#  'Team': 'Clemson',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/157/11520',
#  'Team': 'Colorado',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/156/11520',
#  'Team': 'Colorado St.',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/193/11520', 'Team': 'Duke', 'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/196/11520',
#  'Team': 'East Carolina',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/204/11520',
#  'Team': 'Eastern Mich.',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/231/11520', 'Team': 'FIU', 'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/229/11520',
#  'Team': 'Fla. Atlantic',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/235/11520',
#  'Team': 'Florida',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/234/11520',
#  'Team': 'Florida St.',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/96/11520',
#  'Team': 'Fresno St.',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/253/11520',
#  'Team': 'Ga. Southern',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/257/11520',
#  'Team': 'Georgia',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/254/11520',
#  'Team': 'Georgia St.',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/255/11520',
#  'Team': 'Georgia Tech',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/277/11520',
#  'Team': 'Hawaii',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/288/11520',
#  'Team': 'Houston',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/721/12240',
#  'Team': 'Air Force',
#  'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/295/11520',
#  'Team': 'Idaho',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/301/11520',
#  'Team': 'Illinois',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/306/11520',
#  'Team': 'Indiana',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/312/11520', 'Team': 'Iowa', 'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/311/11520',
#  'Team': 'Iowa St.',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/328/11520',
#  'Team': 'Kansas',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/327/11520',
#  'Team': 'Kansas St.',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/5/12240', 'Team': 'Akron', 'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/8/12240',
#  'Team': 'Alabama',
#  'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/27/12240',
#  'Team': 'Appalachian St.',
#  'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/29/12240',
#  'Team': 'Arizona',
#  'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/28/12240',
#  'Team': 'Arizona St.',
#  'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/31/12240',
#  'Team': 'Arkansas',
#  'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/30/12240',
#  'Team': 'Arkansas St.',
#  'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/331/11520',
#  'Team': 'Kent St.',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/334/11520',
#  'Team': 'Kentucky',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/365/11520', 'Team': 'LSU', 'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/498/11520',
#  'Team': 'La.-Monroe',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/671/11520',
#  'Team': 'Louisiana',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/366/11520',
#  'Team': 'Louisiana Tech',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/367/11520',
#  'Team': 'Louisville',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/388/11520',
#  'Team': 'Marshall',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/392/11520',
#  'Team': 'Maryland',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/400/11520',
#  'Team': 'Massachusetts',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2017&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/721/12424',
#  'Team': 'Air Force',
#  'Year': '2017'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/725/12240',
#  'Team': 'Army West Point',
#  'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/37/12240',
#  'Team': 'Auburn',
#  'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/77/12240', 'Team': 'BYU', 'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/47/12240',
#  'Team': 'Ball St.',
#  'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/51/12240',
#  'Team': 'Baylor',
#  'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/66/12240',
#  'Team': 'Boise St.',
#  'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/67/12240',
#  'Team': 'Boston College',
#  'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/71/12240',
#  'Team': 'Bowling Green',
#  'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/86/12240',
#  'Team': 'Buffalo',
#  'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/107/12240',
#  'Team': 'California',
#  'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/404/11520',
#  'Team': 'Memphis',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/415/11520',
#  'Team': 'Miami (FL)',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/414/11520',
#  'Team': 'Miami (OH)',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/418/11520',
#  'Team': 'Michigan',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/416/11520',
#  'Team': 'Michigan St.',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/419/11520',
#  'Team': 'Middle Tenn.',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2017&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/5/12424', 'Team': 'Akron', 'Year': '2017'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2017&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/8/12424',
#  'Team': 'Alabama',
#  'Year': '2017'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2017&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/27/12424',
#  'Team': 'Appalachian St.',
#  'Year': '2017'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2017&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/29/12424',
#  'Team': 'Arizona',
#  'Year': '2017'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2017&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/28/12424',
#  'Team': 'Arizona St.',
#  'Year': '2017'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2017&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/31/12424',
#  'Team': 'Arkansas',
#  'Year': '2017'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2017&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/30/12424',
#  'Team': 'Arkansas St.',
#  'Year': '2017'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2017&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/725/12424',
#  'Team': 'Army West Point',
#  'Year': '2017'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2017&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/37/12424',
#  'Team': 'Auburn',
#  'Year': '2017'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2017&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/77/12424', 'Team': 'BYU', 'Year': '2017'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/129/12240',
#  'Team': 'Central Mich.',
#  'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/458/12240',
#  'Team': 'Charlotte',
#  'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/140/12240',
#  'Team': 'Cincinnati',
#  'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/147/12240',
#  'Team': 'Clemson',
#  'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/157/12240',
#  'Team': 'Colorado',
#  'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/156/12240',
#  'Team': 'Colorado St.',
#  'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/193/12240', 'Team': 'Duke', 'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/196/12240',
#  'Team': 'East Carolina',
#  'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/204/12240',
#  'Team': 'Eastern Mich.',
#  'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/428/11520',
#  'Team': 'Minnesota',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/430/11520',
#  'Team': 'Mississippi St.',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/434/11520',
#  'Team': 'Missouri',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/490/11520',
#  'Team': 'NC State',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/726/11520', 'Team': 'Navy', 'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/463/11520',
#  'Team': 'Nebraska',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/466/11520',
#  'Team': 'Nevada',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/473/11520',
#  'Team': 'New Mexico',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/472/11520',
#  'Team': 'New Mexico St.',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2017&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/47/12424',
#  'Team': 'Ball St.',
#  'Year': '2017'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2017&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/51/12424',
#  'Team': 'Baylor',
#  'Year': '2017'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2017&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/66/12424',
#  'Team': 'Boise St.',
#  'Year': '2017'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2017&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/67/12424',
#  'Team': 'Boston College',
#  'Year': '2017'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2017&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/71/12424',
#  'Team': 'Bowling Green',
#  'Year': '2017'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2017&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/86/12424',
#  'Team': 'Buffalo',
#  'Year': '2017'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2017&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/107/12424',
#  'Team': 'California',
#  'Year': '2017'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2017&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/129/12424',
#  'Team': 'Central Mich.',
#  'Year': '2017'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2017&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/458/12424',
#  'Team': 'Charlotte',
#  'Year': '2017'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2017&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/140/12424',
#  'Team': 'Cincinnati',
#  'Year': '2017'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/231/12240', 'Team': 'FIU', 'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/229/12240',
#  'Team': 'Fla. Atlantic',
#  'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/235/12240',
#  'Team': 'Florida',
#  'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/234/12240',
#  'Team': 'Florida St.',
#  'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/96/12240',
#  'Team': 'Fresno St.',
#  'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/253/12240',
#  'Team': 'Ga. Southern',
#  'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/257/12240',
#  'Team': 'Georgia',
#  'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/254/12240',
#  'Team': 'Georgia St.',
#  'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/255/12240',
#  'Team': 'Georgia Tech',
#  'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/277/12240',
#  'Team': 'Hawaii',
#  'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/457/11520',
#  'Team': 'North Carolina',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/497/11520',
#  'Team': 'North Texas',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/503/11520',
#  'Team': 'Northern Ill.',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/509/11520',
#  'Team': 'Northwestern',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/513/11520',
#  'Team': 'Notre Dame',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/519/11520', 'Team': 'Ohio', 'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/518/11520',
#  'Team': 'Ohio St.',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/522/11520',
#  'Team': 'Oklahoma',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/521/11520',
#  'Team': 'Oklahoma St.',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/523/11520',
#  'Team': 'Old Dominion',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/433/11520',
#  'Team': 'Ole Miss',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2017&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/147/12424',
#  'Team': 'Clemson',
#  'Year': '2017'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2017&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/149/12424',
#  'Team': 'Coastal Caro.',
#  'Year': '2017'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2017&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/157/12424',
#  'Team': 'Colorado',
#  'Year': '2017'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2017&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/156/12424',
#  'Team': 'Colorado St.',
#  'Year': '2017'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2017&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/193/12424', 'Team': 'Duke', 'Year': '2017'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2017&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/196/12424',
#  'Team': 'East Carolina',
#  'Year': '2017'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2017&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/204/12424',
#  'Team': 'Eastern Mich.',
#  'Year': '2017'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2017&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/231/12424', 'Team': 'FIU', 'Year': '2017'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2017&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/229/12424',
#  'Team': 'Fla. Atlantic',
#  'Year': '2017'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2017&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/235/12424',
#  'Team': 'Florida',
#  'Year': '2017'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/288/12240',
#  'Team': 'Houston',
#  'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/295/12240',
#  'Team': 'Idaho',
#  'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/301/12240',
#  'Team': 'Illinois',
#  'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/306/12240',
#  'Team': 'Indiana',
#  'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/312/12240', 'Team': 'Iowa', 'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/311/12240',
#  'Team': 'Iowa St.',
#  'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/328/12240',
#  'Team': 'Kansas',
#  'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/327/12240',
#  'Team': 'Kansas St.',
#  'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/331/12240',
#  'Team': 'Kent St.',
#  'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/334/12240',
#  'Team': 'Kentucky',
#  'Year': '2016'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/529/11520',
#  'Team': 'Oregon',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/528/11520',
#  'Team': 'Oregon St.',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/539/11520',
#  'Team': 'Penn St.',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/545/11520',
#  'Team': 'Pittsburgh',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/559/11520',
#  'Team': 'Purdue',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/574/11520', 'Team': 'Rice', 'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/587/11520',
#  'Team': 'Rutgers',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/663/11520', 'Team': 'SMU', 'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/626/11520',
#  'Team': 'San Diego St.',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2014&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/630/11520',
#  'Team': 'San Jose St.',
#  'Year': '2014'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2017&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/234/12424',
#  'Team': 'Florida St.',
#  'Year': '2017'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2017&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/96/12424',
#  'Team': 'Fresno St.',
#  'Year': '2017'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2017&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/253/12424',
#  'Team': 'Ga. Southern',
#  'Year': '2017'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2017&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/257/12424',
#  'Team': 'Georgia',
#  'Year': '2017'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2017&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/254/12424',
#  'Team': 'Georgia St.',
#  'Year': '2017'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2017&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/255/12424',
#  'Team': 'Georgia Tech',
#  'Year': '2017'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2017&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/277/12424',
#  'Team': 'Hawaii',
#  'Year': '2017'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2017&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/288/12424',
#  'Team': 'Houston',
#  'Year': '2017'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2017&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/295/12424',
#  'Team': 'Idaho',
#  'Year': '2017'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2017&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/301/12424',
#  'Team': 'Illinois',
#  'Year': '2017'}
# 2017-12-11 10:09:48 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2016&conf_id=-1&division=11&sport_code=MFB>
# ...
# {'Link': 'http://stats.ncaa.org/team/472/11980',
#  'Team': 'New Mexico St.',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/457/11980',
#  'Team': 'North Carolina',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/497/11980',
#  'Team': 'North Texas',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/503/11980',
#  'Team': 'Northern Ill.',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/509/11980',
#  'Team': 'Northwestern',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/513/11980',
#  'Team': 'Notre Dame',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/519/11980', 'Team': 'Ohio', 'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/518/11980',
#  'Team': 'Ohio St.',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/522/11980',
#  'Team': 'Oklahoma',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/521/11980',
#  'Team': 'Oklahoma St.',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/523/11980',
#  'Team': 'Old Dominion',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/433/11980',
#  'Team': 'Ole Miss',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/529/11980',
#  'Team': 'Oregon',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/528/11980',
#  'Team': 'Oregon St.',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/539/11980',
#  'Team': 'Penn St.',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/545/11980',
#  'Team': 'Pittsburgh',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/559/11980',
#  'Team': 'Purdue',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/574/11980', 'Team': 'Rice', 'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/587/11980',
#  'Team': 'Rutgers',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/663/11980', 'Team': 'SMU', 'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/626/11980',
#  'Team': 'San Diego St.',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/630/11980',
#  'Team': 'San Jose St.',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/646/11980',
#  'Team': 'South Ala.',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/648/11980',
#  'Team': 'South Carolina',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/651/11980',
#  'Team': 'South Fla.',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/657/11980',
#  'Team': 'Southern California',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/664/11980',
#  'Team': 'Southern Miss.',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/674/11980',
#  'Team': 'Stanford',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/688/11980',
#  'Team': 'Syracuse',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/698/11980', 'Team': 'TCU', 'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/690/11980',
#  'Team': 'Temple',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/694/11980',
#  'Team': 'Tennessee',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/703/11980',
#  'Team': 'Texas',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/697/11980',
#  'Team': 'Texas A&M',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/670/11980',
#  'Team': 'Texas St.',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/700/11980',
#  'Team': 'Texas Tech',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/709/11980',
#  'Team': 'Toledo',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/716/11980', 'Team': 'Troy', 'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/718/11980',
#  'Team': 'Tulane',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/719/11980',
#  'Team': 'Tulsa',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/9/11980', 'Team': 'UAB', 'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/128/11980', 'Team': 'UCF', 'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/110/11980', 'Team': 'UCLA', 'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/164/11980',
#  'Team': 'UConn',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/465/11980', 'Team': 'UNLV', 'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/704/11980', 'Team': 'UTEP', 'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/706/11980', 'Team': 'UTSA', 'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/732/11980', 'Team': 'Utah', 'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/731/11980',
#  'Team': 'Utah St.',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/736/11980',
#  'Team': 'Vanderbilt',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/746/11980',
#  'Team': 'Virginia',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/742/11980',
#  'Team': 'Virginia Tech',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/749/11980',
#  'Team': 'Wake Forest',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/756/11980',
#  'Team': 'Washington',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/754/11980',
#  'Team': 'Washington St.',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/768/11980',
#  'Team': 'West Virginia',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/772/11980',
#  'Team': 'Western Ky.',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/774/11980',
#  'Team': 'Western Mich.',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/796/11980',
#  'Team': 'Wisconsin',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/inst_team_list?academic_year=2015&conf_id=-1&division=11&sport_code=MFB>
# {'Link': 'http://stats.ncaa.org/team/811/11980',
#  'Team': 'Wyoming',
#  'Year': '2015'}
# 2017-12-11 10:09:52 [scrapy.core.engine] INFO: Closing spider (finished)
# 2017-12-11 10:09:52 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 1220,
#  'downloader/request_count': 4,
#  'downloader/request_method_count/GET': 4,
#  'downloader/response_bytes': 28796,
#  'downloader/response_count': 4,
#  'downloader/response_status_count/200': 4,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2017, 12, 11, 16, 9, 52, 146103),
#  'item_scraped_count': 514,
#  'log_count/DEBUG': 519,
#  'log_count/INFO': 7,
#  'memusage/max': 115892224,
#  'memusage/startup': 115892224,
#  'response_received_count': 4,
#  'scheduler/dequeued': 4,
#  'scheduler/dequeued/memory': 4,
#  'scheduler/enqueued': 4,
#  'scheduler/enqueued/memory': 4,
#  'start_time': datetime.datetime(2017, 12, 11, 16, 9, 44, 983276)}
# 2017-12-11 10:09:52 [scrapy.core.engine] INFO: Spider closed (finished)
