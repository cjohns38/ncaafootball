# %%
import scrapy, os
import pandas as pd
from scrapy.exporters import CsvItemExporter
from scrapy.crawler import CrawlerProcess
from scrapy.linkextractors import LinkExtractor

# %%
class item_roster(scrapy.Item):
    """Scrapy Item for yearly roster"""
    Year = scrapy.Field()
    Team = scrapy.Field()
    Jersey = scrapy.Field()
    Player = scrapy.Field()
    Pos = scrapy.Field()
    Yr = scrapy.Field()
    GP = scrapy.Field()
    GS = scrapy.Field()

# %%
class RosterCSVPipeline(object):
    """Scrapy Pipeline Object for yearly roster"""
    def open_spider(self,spider):
        fileName = "Roster.csv"
        self.file = open(os.path.join("Data", fileName), 'wb')
        self.exporter = CsvItemExporter(self.file, fields_to_export=["Year", "Team", "Jersey","Player","Pos","Yr","GP","GS"])
        self.exporter.start_exporting()
 
    def close_spider(self, spider):
        self.exporter.finish_exporting()
        self.file.close()
 
    def process_item(self, item, spider):
        self.exporter.export_item(item)
        return item

# %%
class rosterSpider(scrapy.Spider): 
    name = "Roster"
    file_in = 'teaminfolinks.csv'
    
    # Read in data
    data = pd.read_csv(os.path.join("Links", file_in))
    df = data[data.key == 'roster'].drop_duplicates()
    df.sort_values(['team'], inplace = True)
    _list = df.to_dict(orient='record')
    
    
    def start_requests(self): 
        
        for url in self._list[:1]: 
            yield scrapy.Request(url=url['link'], 
                                 callback=self.parse, 
                                 meta={'team':url['team']}
                                )
    
    def parse(self, response):
        # year 
        year = response.selector.xpath("//body//div[@id='contentarea']//fieldset//div/" +
                 "/form[@id='change_sport_form']//select[@id='year_list']//option[@select" +
                 "ed='selected']//text()").extract()

        # Create tables 
        tables = pd.read_html(response.body)
        tables[0].columns = tables[0].columns.droplevel(0)
        tables[0]['Year'] = year[0]
        tables[0]['Team'] = response.meta['team']

        for record in tables[0].to_dict(orient='record'): 
            yield item_roster(record)

# %%
process = CrawlerProcess({'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)', 
                          'ITEM_PIPELINES': {'__main__.RosterCSVPipeline':100}
                        })

process.crawl(rosterSpider)
process.start()
# Out:
# 2017-12-11 10:13:17 [scrapy.utils.log] INFO: Scrapy 1.4.0 started (bot: scrapybot)
# 2017-12-11 10:13:17 [scrapy.utils.log] INFO: Overridden settings: {'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'}
# 2017-12-11 10:13:17 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2017-12-11 10:13:17 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2017-12-11 10:13:17 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2017-12-11 10:13:17 [scrapy.middleware] INFO: Enabled item pipelines:
# ['__main__.RosterCSVPipeline']
# 2017-12-11 10:13:17 [scrapy.core.engine] INFO: Spider opened
# 2017-12-11 10:13:17 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2017-12-11 10:13:17 [scrapy.extensions.telnet] DEBUG: Telnet console listening on 127.0.0.1:6023
# 2017-12-11 10:13:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://stats.ncaa.org/team/721/roster/11520> (referer: None)
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 12,
#  'GS': 12,
#  'Jersey': '59',
#  'Player': 'Adenji, Moshood',
#  'Pos': 'OL',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Sr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 6,
#  'GS': 0,
#  'Jersey': '35',
#  'Player': 'Alabi, Justin',
#  'Pos': 'LB',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Fr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 0,
#  'GS': 0,
#  'Jersey': '12',
#  'Player': 'Awini, Jaleel',
#  'Pos': 'QB',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'So'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 5,
#  'GS': 0,
#  'Jersey': '28',
#  'Player': 'Baker, Kalon',
#  'Pos': 'DB',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'So'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 12,
#  'GS': 11,
#  'Jersey': '18',
#  'Player': 'Barnes, Reggie',
#  'Pos': 'LB',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'So'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 10,
#  'GS': 2,
#  'Jersey': '11',
#  'Player': 'Barnes, Myles',
#  'Pos': 'WR',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'So'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 12,
#  'GS': 0,
#  'Jersey': '19',
#  'Player': 'Baska, David',
#  'Pos': 'K',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Sr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 12,
#  'GS': 12,
#  'Jersey': '23',
#  'Player': 'Batts, Steffon',
#  'Pos': 'DB',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Sr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 7,
#  'GS': 0,
#  'Jersey': '98',
#  'Player': 'Beschel, Dillon',
#  'Pos': 'DL',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Jr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 12,
#  'GS': 2,
#  'Jersey': '7',
#  'Player': 'Brown, Garrett',
#  'Pos': 'WR',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'So'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 1,
#  'GS': 0,
#  'Jersey': '54',
#  'Player': 'Bungum, Dylan',
#  'Pos': 'DL',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Jr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 10,
#  'GS': 6,
#  'Jersey': '17',
#  'Player': 'Byrd, Jamal',
#  'Pos': 'DB',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Jr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 12,
#  'GS': 0,
#  'Jersey': '99',
#  'Player': 'Cannada, Briceton',
#  'Pos': 'K',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Sr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 11,
#  'GS': 0,
#  'Jersey': '95',
#  'Player': 'Cannon, Riley',
#  'Pos': 'DL',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Jr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 4,
#  'GS': 0,
#  'Jersey': '56',
#  'Player': 'Carrington, Kevin',
#  'Pos': 'OL',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Sr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 2,
#  'GS': 1,
#  'Jersey': '47',
#  'Player': 'Champaign, Joseph',
#  'Pos': 'DL',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Jr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 0,
#  'GS': 0,
#  'Jersey': '41',
#  'Player': 'Cheeks, Glynn',
#  'Pos': 'LB',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Fr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 0,
#  'GS': 0,
#  'Jersey': '1A',
#  'Player': 'Chubb, Zach',
#  'Pos': 'DB',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Fr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 5,
#  'GS': 0,
#  'Jersey': '33',
#  'Player': 'Clinton-Earl, Aaron',
#  'Pos': nan,
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': nan}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 11,
#  'GS': 0,
#  'Jersey': '30',
#  'Player': 'Conant, Will',
#  'Pos': 'K',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Jr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 1,
#  'GS': 0,
#  'Jersey': '57',
#  'Player': 'Cooksey, Taylor',
#  'Pos': 'OL',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Jr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 1,
#  'GS': 0,
#  'Jersey': '8A',
#  'Player': 'Davis, Pate',
#  'Pos': nan,
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': nan}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 0,
#  'GS': 0,
#  'Jersey': '38',
#  'Player': 'Davis, Markez',
#  'Pos': 'RB',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Fr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 11,
#  'GS': 0,
#  'Jersey': '13',
#  'Player': 'Decoud, Justin',
#  'Pos': 'DB',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Jr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 1,
#  'GS': 0,
#  'Jersey': '92',
#  'Player': 'Deeks, Lochlin',
#  'Pos': nan,
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': nan}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 11,
#  'GS': 0,
#  'Jersey': '46',
#  'Player': 'Dreslinski, Nate',
#  'Pos': 'TE',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Jr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 4,
#  'GS': 0,
#  'Jersey': '81',
#  'Player': 'Duncavage, Luke',
#  'Pos': 'WR',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Jr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 1,
#  'GS': 0,
#  'Jersey': '3A',
#  'Player': 'Dunn, Brett',
#  'Pos': nan,
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': nan}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 12,
#  'GS': 0,
#  'Jersey': '66',
#  'Player': 'Elliott, Harrison',
#  'Pos': 'OL',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Jr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 0,
#  'GS': 0,
#  'Jersey': '8A',
#  'Player': 'Evans, Jerod',
#  'Pos': 'QB',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Fr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 12,
#  'GS': 0,
#  'Jersey': '45',
#  'Player': 'Fisher, Miles',
#  'Pos': 'LB',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Jr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 12,
#  'GS': 10,
#  'Jersey': '97',
#  'Player': 'Fitzgerald, Nick',
#  'Pos': 'DL',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Jr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 11,
#  'GS': 8,
#  'Jersey': '4',
#  'Player': 'Gagliano, Sam',
#  'Pos': 'WR',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Jr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 1,
#  'GS': 0,
#  'Jersey': '10',
#  'Player': 'Gann, Christian',
#  'Pos': 'WR',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Jr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 7,
#  'GS': 5,
#  'Jersey': '42',
#  'Player': 'George, Kristov',
#  'Pos': 'LB',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'So'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 4,
#  'GS': 1,
#  'Jersey': '79',
#  'Player': 'Green, Robert',
#  'Pos': 'DL',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Jr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 12,
#  'GS': 7,
#  'Jersey': '80',
#  'Player': 'Griffin, Garrett',
#  'Pos': 'TE',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'So'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 4,
#  'GS': 0,
#  'Jersey': '26',
#  'Player': 'Hancock, Brent',
#  'Pos': 'WR',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Jr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 12,
#  'GS': 12,
#  'Jersey': '87',
#  'Player': 'Hansen, Alex',
#  'Pos': 'DL',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'So'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 10,
#  'GS': 2,
#  'Jersey': '53',
#  'Player': 'Harris, David',
#  'Pos': 'DL',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Fr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 12,
#  'GS': 10,
#  'Jersey': '32',
#  'Player': 'Hart, Broam',
#  'Pos': 'RB',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Jr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 7,
#  'GS': 0,
#  'Jersey': '61',
#  'Player': 'Hayes, Austin',
#  'Pos': 'OL',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Sr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 9,
#  'GS': 0,
#  'Jersey': '6',
#  'Player': 'Healy, Connor',
#  'Pos': 'LB',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'So'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 12,
#  'GS': 6,
#  'Jersey': '85',
#  'Player': 'Hendricks, Marcus',
#  'Pos': 'TE',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Jr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 12,
#  'GS': 12,
#  'Jersey': '77',
#  'Player': 'Henry, Jerry',
#  'Pos': 'OL',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Sr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 2,
#  'GS': 0,
#  'Jersey': '93',
#  'Player': 'Hoffman, Zach',
#  'Pos': 'K',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Sr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 1,
#  'GS': 0,
#  'Jersey': '73',
#  'Player': 'Holba, Andrew',
#  'Pos': 'OL',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'So'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 1,
#  'GS': 0,
#  'Jersey': '83',
#  'Player': 'Huff, Riley',
#  'Pos': 'TE',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'So'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 12,
#  'GS': 4,
#  'Jersey': '14',
#  'Player': 'Huntsman, Colton',
#  'Pos': 'WR',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Jr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 12,
#  'GS': 12,
#  'Jersey': '65',
#  'Player': 'Husar, Jr., Michael',
#  'Pos': 'OL',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Sr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 0,
#  'GS': 0,
#  'Jersey': '43',
#  'Player': 'Imamura, Ian',
#  'Pos': 'LB',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'So'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 9,
#  'GS': 0,
#  'Jersey': '29',
#  'Player': 'Johnson, D.J.',
#  'Pos': 'RB',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Fr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 10,
#  'GS': 5,
#  'Jersey': '8',
#  'Player': 'Jones, Jared',
#  'Pos': 'LB',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Jr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 5,
#  'GS': 0,
#  'Jersey': '63',
#  'Player': 'Jones, David',
#  'Pos': 'OL',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Jr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 7,
#  'GS': 1,
#  'Jersey': '68',
#  'Player': 'Kerber, Drew',
#  'Pos': 'OL',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Sr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 12,
#  'GS': 0,
#  'Jersey': '34',
#  'Player': 'Kohn, Demario',
#  'Pos': 'RB',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Jr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 12,
#  'GS': 6,
#  'Jersey': '37',
#  'Player': 'Lacoste, Anthony',
#  'Pos': 'DB',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Sr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 0,
#  'GS': 0,
#  'Jersey': '5A',
#  'Player': 'Lacy, Jalen',
#  'Pos': 'LB',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Fr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 12,
#  'GS': 0,
#  'Jersey': '25',
#  'Player': 'Ladipo, Roland',
#  'Pos': 'DB',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Fr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 10,
#  'GS': 4,
#  'Jersey': '24',
#  'Player': 'Lee, Jonathan',
#  'Pos': 'RB',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Jr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 12,
#  'GS': 0,
#  'Jersey': '82',
#  'Player': 'Link, Keith',
#  'Pos': 'TE',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Jr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 9,
#  'GS': 0,
#  'Jersey': '9C',
#  'Player': 'Linn, Hayes',
#  'Pos': nan,
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': nan}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 12,
#  'GS': 12,
#  'Jersey': '62',
#  'Player': 'Lore, David',
#  'Pos': 'OL',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Sr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 11,
#  'GS': 0,
#  'Jersey': '78',
#  'Player': 'Lovett, Ross',
#  'Pos': 'OL',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Sr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 11,
#  'GS': 7,
#  'Jersey': '15',
#  'Player': 'Ludowig, Alex',
#  'Pos': 'WR',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'So'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 9,
#  'GS': 7,
#  'Jersey': '96',
#  'Player': 'Luebbe, Dana',
#  'Pos': 'DL',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Sr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 3,
#  'GS': 1,
#  'Jersey': '27',
#  'Player': 'MacArthur, Ty',
#  'Pos': 'WR',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Sr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 2,
#  'GS': 0,
#  'Jersey': '60',
#  'Player': 'Manuel, Jimmy',
#  'Pos': 'OL',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Jr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 6,
#  'GS': 0,
#  'Jersey': '2A',
#  'Player': 'Mayes, Jordan',
#  'Pos': 'DB',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Jr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 0,
#  'GS': 0,
#  'Jersey': '69',
#  'Player': 'McBee, Payden',
#  'Pos': 'OL',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Jr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 12,
#  'GS': 12,
#  'Jersey': '20',
#  'Player': 'McHenry, Gavin',
#  'Pos': 'DB',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'So'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 7,
#  'GS': 0,
#  'Jersey': '3',
#  'Player': 'Miller, Chris',
#  'Pos': 'DB',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Sr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 9,
#  'GS': 9,
#  'Jersey': '49',
#  'Player': 'Nichol, Joey',
#  'Pos': 'LB',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Jr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 1,
#  'GS': 0,
#  'Jersey': '67',
#  'Player': 'Njemanze, Jabree',
#  'Pos': 'OL',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'So'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 5,
#  'GS': 0,
#  'Jersey': '64',
#  'Player': 'Noyes, Patrick',
#  'Pos': 'OL',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Jr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 2,
#  'GS': 0,
#  'Jersey': '9B',
#  'Player': 'Oehrle, Drew',
#  'Pos': 'K',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'So'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 1,
#  'GS': 0,
#  'Jersey': '84',
#  'Player': 'Onwuzu, Nelson',
#  'Pos': 'WR',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'So'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 2,
#  'GS': 0,
#  'Jersey': '48',
#  'Player': 'Onyechi, Jacob',
#  'Pos': nan,
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': nan}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 2,
#  'GS': 1,
#  'Jersey': '2',
#  'Player': 'Pearson, Kale',
#  'Pos': 'QB',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Jr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 12,
#  'GS': 3,
#  'Jersey': '51',
#  'Player': 'Pierce, Jordan',
#  'Pos': nan,
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': nan}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 12,
#  'GS': 12,
#  'Jersey': '36',
#  'Player': 'Proctor, Spencer',
#  'Pos': 'LB',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Jr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 6,
#  'GS': 0,
#  'Jersey': '74',
#  'Player': 'Remmo, Sevrin',
#  'Pos': 'OL',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'So'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 0,
#  'GS': 0,
#  'Jersey': '44',
#  'Player': 'Riley, Jake',
#  'Pos': 'LB',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Fr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 10,
#  'GS': 3,
#  'Jersey': '6A',
#  'Player': 'Roberts, Karson',
#  'Pos': 'QB',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'So'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 12,
#  'GS': 2,
#  'Jersey': '9',
#  'Player': 'Robinette, Jalen',
#  'Pos': 'WR',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Fr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 12,
#  'GS': 12,
#  'Jersey': '72',
#  'Player': 'Rochell, Matt',
#  'Pos': 'OL',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'So'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 9,
#  'GS': 5,
#  'Jersey': '6B',
#  'Player': 'Romine, Nate',
#  'Pos': 'QB',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Fr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 11,
#  'GS': 0,
#  'Jersey': '58',
#  'Player': 'Ruechel, A.J.',
#  'Pos': 'OL',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'So'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 12,
#  'GS': 0,
#  'Jersey': '31',
#  'Player': 'Rushing, Devin',
#  'Pos': nan,
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': nan}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 1,
#  'GS': 0,
#  'Jersey': '52',
#  'Player': 'Salimu, Yohance',
#  'Pos': 'DL',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'So'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 5,
#  'GS': 0,
#  'Jersey': '22',
#  'Player': 'Solano, Paco',
#  'Pos': 'RB',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Jr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 12,
#  'GS': 12,
#  'Jersey': '21',
#  'Player': 'Spears, Christian',
#  'Pos': 'DB',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Jr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 8,
#  'GS': 0,
#  'Jersey': '6A',
#  'Player': 'Steelhammer, Weston',
#  'Pos': 'DB',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Fr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 1,
#  'GS': 0,
#  'Jersey': '9A',
#  'Player': 'Stevenson, Marcus',
#  'Pos': 'RB',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Jr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 12,
#  'GS': 0,
#  'Jersey': '55',
#  'Player': 'Sumpter, Steven',
#  'Pos': 'LB',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Jr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 12,
#  'GS': 2,
#  'Jersey': '91',
#  'Player': 'Timmerman, Troy',
#  'Pos': 'DL',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Jr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 2,
#  'GS': 0,
#  'Jersey': '70',
#  'Player': 'Uzo-Okereke, Ar',
#  'Pos': nan,
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': nan}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 12,
#  'GS': 8,
#  'Jersey': '5',
#  'Player': 'Walker, Dexter',
#  'Pos': 'DB',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'So'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 11,
#  'GS': 1,
#  'Jersey': '40',
#  'Player': 'Watson, Ryan',
#  'Pos': 'DL',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Fr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 11,
#  'GS': 1,
#  'Jersey': '39',
#  'Player': 'Wharton, Donnie',
#  'Pos': nan,
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': nan}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 0,
#  'GS': 0,
#  'Jersey': '48',
#  'Player': 'Wiernicki, Johnny',
#  'Pos': 'RB',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Fr'}
# 2017-12-11 10:13:21 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/team/721/roster/11520>
# {'GP': 7,
#  'GS': 0,
#  'Jersey': '71',
#  'Player': 'Zemko, Charles',
#  'Pos': 'OL',
#  'Team': 'Air Force Falcons',
#  'Year': '2013-14',
#  'Yr': 'Sr'}
# 2017-12-11 10:13:21 [scrapy.core.engine] INFO: Closing spider (finished)
# 2017-12-11 10:13:21 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 250,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 8084,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2017, 12, 11, 16, 13, 21, 244855),
#  'item_scraped_count': 102,
#  'log_count/DEBUG': 104,
#  'log_count/INFO': 7,
#  'memusage/max': 119103488,
#  'memusage/startup': 119103488,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2017, 12, 11, 16, 13, 17, 924582)}
# 2017-12-11 10:13:21 [scrapy.core.engine] INFO: Spider closed (finished)
