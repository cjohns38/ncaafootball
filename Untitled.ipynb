# %%
import pandas as pd
import requests, scrapy

# %%
data = pd.read_csv('StatsLinks.csv').to_dict(orient='record')

# %%
data[0]['Link']
# Out:
# 'http://stats.ncaa.org/team/721/stats?id=11980&year_stat_category_id=10762'

# %%
test = {}
for x in data: 
    r = requests.get(x['Link'])
    tables = pd.read_html(r.content)
    table = tables[2]
    stop_index = [1 if 'Unnamed: ' in column  else 0 for idx, column in enumerate(table.columns)].index(1)
    columnNamesFixed = {col:col.replace(" ","").replace("/","").replace(".","") for col in table.iloc[:,:stop_index].columns}
    table.rename(columns = columnNamesFixed, inplace = True)
    final_table = table[:-3].iloc[:,:stop_index]
    test[x['Stat']] = final_table

# %%
def table_cleaner(html, target_table, trim_n_rows = 0):
    """Read HTML string and return a table
       html : HTML string
       target_table : Target table number
       trim_n_rows : Trim X number of rows from the end of the table (enter as positive number)
    """
    tables = pd.read_html(html)
    table = tables[target_table]
    stop_index = [1 if 'Unnamed: ' in column  else 0 for idx, column in enumerate(table.columns)].index(1)
    columnNamesFixed = {col:col.replace(" ","").replace("/","").replace(".","") for col in table.iloc[:,:stop_index].columns}
    table.rename(columns = columnNamesFixed, inplace = True)
    return table[:-trim_n_rows].iloc[:,:stop_index]

# %%
#r = requests.get(data[0]['Link'])

# %%
table_cleaner(r.content, 2, 3)
# Out:
#    Jersey               Player   Yr  Pos  GP  GS   G  PassAttempts  \
# 0      87    Hansen, Alexander   Jr   DL  13  13  13           NaN
# 1      91      Timmerman, Troy   Sr   DL  13  13  13           NaN
# 2      95        Cannon, Riley   Sr   DL  13   0  13           NaN
# 3      20       McHenry, Gavin   Jr   DB  13   6  13           NaN
# 4      13       Decoud, Justin   Sr   DB  13   8  13           NaN
# 5      98      Beschel, Dillon   Sr   DL  13   0  13           NaN
# 6      30         Conant, Will   Sr    K  13   0  13           NaN
# 7      21    Spears, Christian   Sr   DB  13  13  13           NaN
# 8      2A        Mayes, Jordan   Sr   DB  13   9  13           NaN
# 9      94         Oehrle, Drew   Jr    K  13   0  13           NaN
# 10     72        Rochell, Matt   Jr   OL  13  13  13           NaN
# 11     58      Ruechel, Andrew   Jr   OL  13  13  13           NaN
# 12      9     Robinette, Jalen   So   WR  13  11  13           2.0
# 13      8  Steelhammer, Weston   So   DB  13  11  13           NaN
# 14     25       Ladipo, Roland   So   DB  13   0  13           NaN
# 15     5R       Rushing, Devin   Jr   RB  13   3  13           NaN
# 16     29          Linn, Hayes   So   DB  13   0  13           NaN
# 17     47    Alexander, Claude   So   LB  13   0  13           NaN
# 18     46     Dreslinski, Nate   Sr   TE  13   1  13           NaN
# 19      6        Healy, Connor   Jr   LB  13  13  13           NaN
# 20     97     Fitzgerald, Nick   Sr   DL  13  13  13           NaN
# 21     51       Pierce, Jordan   Sr   LB  13  12  13           NaN
# 22     65  Husar, Jr., Michael   Sr   OL  13  13  13           NaN
# 23     36     Proctor, Spencer   Sr   LB  13  13  13           NaN
# 24     64       Noyes, Patrick   Sr   OL  12  10  12           NaN
# 25     11        Barnes, Myles   Jr   WR  12   0  12           NaN
# 26     53        Harris, David   So   DL  12   0  12           NaN
# 27     40         Watson, Ryan   So   DL  12   0  12           NaN
# 28     60        Manuel, Jimmy   Sr   OL  12   0  12           NaN
# 29      2        Pearson, Kale   Sr   QB  12  12  12         171.0
# ..    ...                  ...  ...  ...  ..  ..  ..           ...
# 55     39      Wharton, Donnie   Sr   LB   7   0   7           NaN
# 56     32          Hart, Broam   Sr   RB   7   2   7           NaN
# 57     44          Ross, Grant  NaN  NaN   6   0   6           NaN
# 58     6A         Romine, Nate   So   QB   5   1   5          30.0
# 59     79        Green, Robert   Sr   DL   5   0   5           NaN
# 60     49         Nichol, Joey   Sr   LB   4   1   4           NaN
# 61     73       Caunitz, Allen   So   OL   4   1   4           NaN
# 62     93        Byers, Samuel   So   DL   4   0   4           NaN
# 63     34           Dunn, Haji   So   LB   3   0   3           NaN
# 64     16      Roberts, Karson   Jr   QB   3   0   3           NaN
# 65     27      Driskell, Bryan   So   RB   3   0   3           NaN
# 66     52    Halloran, Patrick   So   OL   3   0   3           NaN
# 67     74        Remmo, Sevrin   Jr   OL   3   3   3           NaN
# 68     70      Uzo-Okereke, Ar   Jr   OL   3   0   3           NaN
# 69     67          Vail, Dylan   So   OL   2   0   2           NaN
# 70     18        Hicks, Brodie   Fr   WR   2   0   2           NaN
# 71     2W      Williams, Tyler   Fr   QB   2   0   2           NaN
# 72     69      Darling, Daniel   So   OL   2   0   2           NaN
# 73     26      Hancock, Tucker  NaN  NaN   2   0   2           NaN
# 74     42      George, Kristov   Jr   LB   1   0   1           NaN
# 75     54        Bungum, Dylan   Sr   DL   1   0   1           NaN
# 76     33  Clinton-Earl, Aaron   Jr   RB   1   0   1           NaN
# 77     19        Hill, Brayden   So   DB   1   0   1           NaN
# 78     3W        Bronkar, Cody   Fr   WR   1   0   1           NaN
# 79     38    Cleveland, Kellen   So   LB   1   0   1           NaN
# 80     4R        Hester, Scott   So   RB   1   0   1           NaN
# 81     57      Sutton, Michael   Fr   OL   1   0   1           NaN
# 82     61      Wilson, Jackson   So   OL   1   0   1           NaN
# 83     89     Zuberer, Grayson   So   TE   1   0   1           NaN
# 84     90          Allen, Reed   Jr   DL   1   0   1           NaN
#
#    Completions Interceptions PassYards PassTDs  PassEff  CompletionsPerGame  \
# 0          NaN           NaN       NaN     NaN      NaN                0.00
# 1          NaN           NaN       NaN     NaN      NaN                0.00
# 2          NaN           NaN       NaN     NaN      NaN                0.00
# 3          NaN           NaN       NaN     NaN      NaN                0.00
# 4          NaN           NaN       NaN     NaN      NaN                0.00
# 5          NaN           NaN       NaN     NaN      NaN                0.00
# 6          NaN           NaN       NaN     NaN      NaN                0.00
# 7          NaN           NaN       NaN     NaN      NaN                0.00
# 8          NaN           NaN       NaN     NaN      NaN                0.00
# 9          NaN           NaN       NaN     NaN      NaN                0.00
# 10         NaN           NaN       NaN     NaN      NaN                0.00
# 11         NaN           NaN       NaN     NaN      NaN                0.00
# 12           1           NaN        54       1   441.80                0.08
# 13         NaN           NaN       NaN     NaN      NaN                0.00
# 14         NaN           NaN       NaN     NaN      NaN                0.00
# 16              NaN            NaN        0.00
# 17              NaN            NaN        0.00
# 18              NaN            NaN        0.00
# 19              NaN            NaN        0.00
# 20              NaN            NaN        0.00
# 21              NaN            NaN        0.00
# 22              NaN            NaN        0.00
# 23              NaN            NaN        0.00
# 24              NaN            NaN        0.00
# 25              NaN            NaN        0.00
# 26              NaN            NaN        0.00
# 27              NaN            NaN        0.00
# 28              NaN            NaN        0.00
# 29           15.743          0.591      132.50
# ..              ...            ...         ...
# 55              NaN            NaN        0.00
# 56              NaN            NaN        0.00
# 57              NaN            NaN        0.00
# 58           14.857          0.467       41.60
# 59              NaN            NaN        0.00
# 60              NaN            NaN        0.00
# 61              NaN            NaN        0.00
# 62              NaN            NaN        0.00
# 63              NaN            NaN        0.00
# 64              NaN            NaN        0.00
# 65              NaN            NaN        0.00
# 66              NaN            NaN        0.00
# 67              NaN            NaN        0.00
# 68              NaN            NaN        0.00
# 69              NaN            NaN        0.00
# 70              NaN            NaN        0.00
# 71              NaN            NaN        0.00
# 72              NaN            NaN        0.00
# 73              NaN            NaN        0.00
# 74              NaN            NaN        0.00
# 75              NaN            NaN        0.00
# 76              NaN            NaN        0.00
# 77              NaN            NaN        0.00
# 78              NaN            NaN        0.00
# 79              NaN            NaN        0.00
# 80              NaN            NaN        0.00
# 81              NaN            NaN        0.00
# 82              NaN            NaN        0.00
# 83              NaN            NaN        0.00
# 84              NaN            NaN        0.00
#
# [85 rows x 17 columns]

# %%
# Out:
# Index(['Jersey', 'Player', 'Yr', 'Pos', 'GP', 'GS', 'G', 'PassAttempts',
#        'Completions', 'Interceptions', 'PassYards', 'PassTDs', 'PassEff',
#        'CompletionsPerGame', 'YdsPerCompletion', 'CompletionPct',
#        'PassYardsG'],
#       dtype='object')

# %%
from scrapy.item import DictItem, Field

def create_item_class(class_name,field_list):
    field_dict = {}
    for field_name in field_list:
        field_dict[field_name] = Field()

    return type(class_name, (DictItem,), {'fields':field_dict})

# %%
field_list = test['Participation'].columns
DynamicItem = create_item_class('passing', field_list)
passing = DynamicItem()

# %%
passing.fields
# Out:
# {'G': {}, 'GP': {}, 'GS': {}, 'Jersey': {}, 'Player': {}, 'Pos': {}, 'Yr': {}}

# %%
class item2(scrapy.Item):
    """Scrapy Item Team History"""
    Jersey = scrapy.Field()
    Player = scrapy.Field()
    Yr = scrapy.Field()
    Pos = scrapy.Field()
    GP = scrapy.Field()
    GS = scrapy.Field()
    G = scrapy.Field()

# %%
for record in test['Participation'].to_dict(orient='record'):
    for k, v in record.items(): 
        passing[k] = v

# %%
for record in test['Participation'].to_dict(orient='record')[:1]:
    x = item2(record)
    print(x.__dict__)
# Out:
# {'_values': {'Jersey': '87', 'Player': 'Hansen, Alexander', 'Yr': 'Jr', 'Pos': 'DL', 'GP': '13', 'GS': '13', 'G': 13}}

# %%
passing.__dict__
# Out:
# {'_values': {'G': 1,
#   'GP': '1',
#   'GS': '0',
#   'Jersey': '90',
#   'Player': 'Allen, Reed',
#   'Pos': 'DL',
#   'Yr': 'Jr'}}

# %%
item2
# Out:
# __main__.item2
