# %%
import scrapy, re, urllib, datetime, io, requests, os
import pandas as pd
from scrapy.exporters import CsvItemExporter
from scrapy.crawler import CrawlerProcess
from scrapy.linkextractors import LinkExtractor
from bs4 import BeautifulSoup as bs

# %%
class item_history(scrapy.Item):
    """Scrapy Item Team History"""
    Team = scrapy.Field()
    Year = scrapy.Field()
    HeadCoaches = scrapy.Field()
    Division = scrapy.Field()
    Conference = scrapy.Field()
    Wins = scrapy.Field()
    Losses = scrapy.Field()
    Ties = scrapy.Field()
    WL = scrapy.Field()
    Notes = scrapy.Field()

# %%
class RosterCSVPipeline(object):
    """Scrapy Pipeline Object for History"""
    
    def open_spider(self,spider):
        fileName = "History.csv"
        self.file = open(os.path.join("Data", fileName), 'wb')
        self.exporter = CsvItemExporter(self.file, fields_to_export=["Team","Year","Head Coaches","Division","Conference","Wins","Losses","Ties","WL","Notes"])
        self.exporter.start_exporting()
 
    def close_spider(self, spider):
        self.exporter.finish_exporting()
        self.file.close()
 
    def process_item(self, item, spider):
        self.exporter.export_item(item)
        return item

# %%
class HistorySpider(scrapy.Spider): 
    name = "History"
    file_in = 'links.csv'
    
    # Read in data
    data = pd.read_csv(os.path.join("Data", file_in))
    df = data[data.key == 'history'].drop_duplicates()
    df.sort_values(['team'], inplace = True)
    _list = df.to_dict(orient='record')
    
    def start_requests(self): 
        
        for url in self._list[:1]: 
            yield scrapy.Request(url=url['link'], 
                                 callback=self.parse, 
                                 meta={'team':url['team']}
                                )
    
    def parse(self, response):         
        # Create tables 
        tables = pd.read_html(response.body)
        tables[0]['Team'] = response.meta['team']
        tables[0].rename(columns={"WL%":"WL", "Head Coaches":"HeadCoaches"}, inplace = True)
        
        for record in tables[0][:-1].to_dict(orient='record'): 
            yield item_history(record)

# %%
process = CrawlerProcess({'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)',
                          'ITEM_PIPELINES': {'__main__.RosterCSVPipeline':100}
                         })

process.crawl(HistorySpider)
process.start()
# Out:
# 2017-12-11 09:35:32 [scrapy.utils.log] INFO: Scrapy 1.4.0 started (bot: scrapybot)
# 2017-12-11 09:35:32 [scrapy.utils.log] INFO: Overridden settings: {'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'}
# 2017-12-11 09:35:32 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2017-12-11 09:35:32 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2017-12-11 09:35:32 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2017-12-11 09:35:32 [scrapy.middleware] INFO: Enabled item pipelines:
# ['__main__.RosterCSVPipeline']
# 2017-12-11 09:35:32 [scrapy.core.engine] INFO: Spider opened
# 2017-12-11 09:35:32 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2017-12-11 09:35:32 [scrapy.extensions.telnet] DEBUG: Telnet console listening on 127.0.0.1:6023
# 2017-12-11 09:35:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://stats.ncaa.org/teams/history/MFB/721> (referer: None)
# 2017-12-11 09:35:36 [chardet.charsetprober] DEBUG: EUC-TW Taiwan prober hit error at byte 54
# 2017-12-11 09:35:38 [chardet.charsetprober] DEBUG: utf-8  confidence = 0.505
# 2017-12-11 09:35:38 [chardet.charsetprober] DEBUG: SHIFT_JIS Japanese confidence = 0.01
# 2017-12-11 09:35:38 [chardet.charsetprober] DEBUG: EUC-JP Japanese confidence = 0.01
# 2017-12-11 09:35:38 [chardet.charsetprober] DEBUG: GB2312 Chinese confidence = 0.01
# 2017-12-11 09:35:38 [chardet.charsetprober] DEBUG: EUC-KR Korean confidence = 0.01
# 2017-12-11 09:35:38 [chardet.charsetprober] DEBUG: CP949 Korean confidence = 0.01
# 2017-12-11 09:35:38 [chardet.charsetprober] DEBUG: Big5 Chinese confidence = 0.01
# 2017-12-11 09:35:38 [chardet.charsetprober] DEBUG: EUC-TW not active
# 2017-12-11 09:35:38 [chardet.charsetprober] DEBUG: windows-1251 Russian confidence = 0.01
# 2017-12-11 09:35:38 [chardet.charsetprober] DEBUG: KOI8-R Russian confidence = 0.01
# 2017-12-11 09:35:38 [chardet.charsetprober] DEBUG: ISO-8859-5 Russian confidence = 0.01
# 2017-12-11 09:35:38 [chardet.charsetprober] DEBUG: MacCyrillic Russian confidence = 0.01
# 2017-12-11 09:35:38 [chardet.charsetprober] DEBUG: IBM866 Russian confidence = 0.01
# 2017-12-11 09:35:38 [chardet.charsetprober] DEBUG: IBM855 Russian confidence = 0.01
# 2017-12-11 09:35:38 [chardet.charsetprober] DEBUG: ISO-8859-7 Greek confidence = 0.01
# 2017-12-11 09:35:38 [chardet.charsetprober] DEBUG: windows-1253 Greek confidence = 0.01
# 2017-12-11 09:35:38 [chardet.charsetprober] DEBUG: ISO-8859-5 Bulgairan confidence = 0.01
# 2017-12-11 09:35:38 [chardet.charsetprober] DEBUG: windows-1251 Bulgarian confidence = 0.01
# 2017-12-11 09:35:38 [chardet.charsetprober] DEBUG: TIS-620 Thai confidence = 0.0
# 2017-12-11 09:35:38 [chardet.charsetprober] DEBUG: ISO-8859-9 Turkish confidence = 0.29214509392456667
# 2017-12-11 09:35:38 [chardet.charsetprober] DEBUG: windows-1255 Hebrew confidence = 0.0
# 2017-12-11 09:35:38 [chardet.charsetprober] DEBUG: windows-1255 Hebrew confidence = 0.0
# 2017-12-11 09:35:38 [chardet.charsetprober] DEBUG: windows-1255 Hebrew confidence = 0.0
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': 'Mountain West',
#  'Division': 'FBS',
#  'HeadCoaches': 'Troy Calhoun',
#  'Losses': 7,
#  'Notes': nan,
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.41700000000000004,
#  'Wins': 5,
#  'Year': '2017-18'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': 'Mountain West',
#  'Division': 'FBS',
#  'HeadCoaches': 'Troy Calhoun',
#  'Losses': 3,
#  'Notes': nan,
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.769,
#  'Wins': 10,
#  'Year': '2016-17'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': 'Mountain West',
#  'Division': 'FBS',
#  'HeadCoaches': 'Troy Calhoun',
#  'Losses': 6,
#  'Notes': nan,
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.5710000000000001,
#  'Wins': 8,
#  'Year': '2015-16'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': 'Mountain West',
#  'Division': 'FBS',
#  'HeadCoaches': 'Troy Calhoun',
#  'Losses': 3,
#  'Notes': nan,
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.769,
#  'Wins': 10,
#  'Year': '2014-15'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': 'Mountain West',
#  'Division': 'FBS',
#  'HeadCoaches': 'Troy Calhoun',
#  'Losses': 10,
#  'Notes': nan,
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.16699999999999998,
#  'Wins': 2,
#  'Year': '2013-14'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': 'Mountain West',
#  'Division': 'FBS',
#  'HeadCoaches': 'Troy Calhoun',
#  'Losses': 7,
#  'Notes': nan,
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.462,
#  'Wins': 6,
#  'Year': '2012-13'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': 'Mountain West',
#  'Division': 'FBS',
#  'HeadCoaches': 'Troy Calhoun',
#  'Losses': 6,
#  'Notes': 'Military Bowl',
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.5379999999999999,
#  'Wins': 7,
#  'Year': '2011-12'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': 'Mountain West',
#  'Division': 'FBS',
#  'HeadCoaches': 'Troy Calhoun',
#  'Losses': 4,
#  'Notes': 'Independence Bowl',
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.6920000000000001,
#  'Wins': 9,
#  'Year': '2010-11'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': 'Mountain West',
#  'Division': 'FBS',
#  'HeadCoaches': 'Troy Calhoun',
#  'Losses': 5,
#  'Notes': 'Armed Forces Bowl',
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.615,
#  'Wins': 8,
#  'Year': '2009-10'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': 'Mountain West',
#  'Division': 'FBS',
#  'HeadCoaches': 'Troy Calhoun',
#  'Losses': 5,
#  'Notes': 'Armed Forces Bowl',
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.615,
#  'Wins': 8,
#  'Year': '2008-09'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': 'Mountain West',
#  'Division': 'FBS',
#  'HeadCoaches': 'Troy Calhoun',
#  'Losses': 4,
#  'Notes': 'Armed Forces Bowl',
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.6920000000000001,
#  'Wins': 9,
#  'Year': '2007-08'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': 'Mountain West',
#  'Division': 'FBS',
#  'HeadCoaches': 'Fisher DeBerry',
#  'Losses': 8,
#  'Notes': nan,
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.33299999999999996,
#  'Wins': 4,
#  'Year': '2006-07'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': 'Mountain West',
#  'Division': 'FBS',
#  'HeadCoaches': 'Fisher DeBerry',
#  'Losses': 7,
#  'Notes': nan,
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.364,
#  'Wins': 4,
#  'Year': '2005-06'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': 'Mountain West',
#  'Division': 'FBS',
#  'HeadCoaches': 'Fisher DeBerry',
#  'Losses': 6,
#  'Notes': nan,
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.455,
#  'Wins': 5,
#  'Year': '2004-05'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': 'Mountain West',
#  'Division': 'FBS',
#  'HeadCoaches': 'Fisher DeBerry',
#  'Losses': 5,
#  'Notes': nan,
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.583,
#  'Wins': 7,
#  'Year': '2003-04'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': 'Mountain West',
#  'Division': 'FBS',
#  'HeadCoaches': 'Fisher DeBerry',
#  'Losses': 5,
#  'Notes': 'San Francisco Bowl',
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.615,
#  'Wins': 8,
#  'Year': '2002-03'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': 'Mountain West',
#  'Division': 'FBS',
#  'HeadCoaches': 'Fisher DeBerry',
#  'Losses': 6,
#  'Notes': nan,
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.5,
#  'Wins': 6,
#  'Year': '2001-02'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': 'Mountain West',
#  'Division': 'FBS',
#  'HeadCoaches': 'Fisher DeBerry',
#  'Losses': 3,
#  'Notes': 'Silicon Valley Bowl',
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.75,
#  'Wins': 9,
#  'Year': '2000-01'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': '-',
#  'Division': 'FBS',
#  'HeadCoaches': 'Fisher DeBerry',
#  'Losses': 5,
#  'Notes': nan,
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.545,
#  'Wins': 6,
#  'Year': '1999-00'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': '-',
#  'Division': 'FBS',
#  'HeadCoaches': 'Fisher DeBerry',
#  'Losses': 1,
#  'Notes': 'Oahu Bowl',
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.9229999999999999,
#  'Wins': 12,
#  'Year': '1998-99'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': '-',
#  'Division': 'FBS',
#  'HeadCoaches': 'Fisher DeBerry',
#  'Losses': 3,
#  'Notes': 'Las Vegas Bowl',
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.769,
#  'Wins': 10,
#  'Year': '1997-98'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': '-',
#  'Division': 'FBS',
#  'HeadCoaches': 'Fisher DeBerry',
#  'Losses': 5,
#  'Notes': nan,
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.545,
#  'Wins': 6,
#  'Year': '1996-97'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': '-',
#  'Division': 'FBS',
#  'HeadCoaches': 'Fisher DeBerry',
#  'Losses': 5,
#  'Notes': 'Copper Bowl',
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.615,
#  'Wins': 8,
#  'Year': '1995-96'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': '-',
#  'Division': 'FBS',
#  'HeadCoaches': 'Fisher DeBerry',
#  'Losses': 4,
#  'Notes': nan,
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.667,
#  'Wins': 8,
#  'Year': '1994-95'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': '-',
#  'Division': 'FBS',
#  'HeadCoaches': 'Fisher DeBerry',
#  'Losses': 8,
#  'Notes': nan,
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.33299999999999996,
#  'Wins': 4,
#  'Year': '1993-94'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': '-',
#  'Division': 'FBS',
#  'HeadCoaches': 'Fisher DeBerry',
#  'Losses': 5,
#  'Notes': 'Liberty Bowl',
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.583,
#  'Wins': 7,
#  'Year': '1992-93'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': '-',
#  'Division': 'FBS',
#  'HeadCoaches': 'Fisher DeBerry',
#  'Losses': 3,
#  'Notes': 'Liberty Bowl',
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.769,
#  'Wins': 10,
#  'Year': '1991-92'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': '-',
#  'Division': 'FBS',
#  'HeadCoaches': 'Fisher DeBerry',
#  'Losses': 5,
#  'Notes': 'Liberty Bowl',
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.583,
#  'Wins': 7,
#  'Year': '1990-91'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': '-',
#  'Division': 'FBS',
#  'HeadCoaches': 'Fisher DeBerry',
#  'Losses': 4,
#  'Notes': 'Liberty Bowl',
#  'Team': 'Air Force Falcons',
#  'Ties': 1,
#  'WL': 0.654,
#  'Wins': 8,
#  'Year': '1989-90'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': '-',
#  'Division': 'FBS',
#  'HeadCoaches': 'Fisher DeBerry',
#  'Losses': 7,
#  'Notes': nan,
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.41700000000000004,
#  'Wins': 5,
#  'Year': '1988-89'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': '-',
#  'Division': 'FBS',
#  'HeadCoaches': 'Fisher DeBerry',
#  'Losses': 4,
#  'Notes': 'Freedom Bowl',
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.6920000000000001,
#  'Wins': 9,
#  'Year': '1987-88'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': '-',
#  'Division': 'FBS',
#  'HeadCoaches': 'Fisher DeBerry',
#  'Losses': 5,
#  'Notes': nan,
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.545,
#  'Wins': 6,
#  'Year': '1986-87'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': '-',
#  'Division': 'FBS',
#  'HeadCoaches': 'Fisher DeBerry',
#  'Losses': 1,
#  'Notes': 'Bluebonnet Bowl',
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.9229999999999999,
#  'Wins': 12,
#  'Year': '1985-86'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': '-',
#  'Division': 'FBS',
#  'HeadCoaches': 'Fisher DeBerry',
#  'Losses': 4,
#  'Notes': 'Independence Bowl',
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.667,
#  'Wins': 8,
#  'Year': '1984-85'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': '-',
#  'Division': 'FBS',
#  'HeadCoaches': 'Ken Hatfield',
#  'Losses': 2,
#  'Notes': 'Independence Bowl',
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.833,
#  'Wins': 10,
#  'Year': '1983-84'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': '-',
#  'Division': 'FBS',
#  'HeadCoaches': 'Ken Hatfield',
#  'Losses': 5,
#  'Notes': 'Hall of Fame Bowl',
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.615,
#  'Wins': 8,
#  'Year': '1982-83'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': '-',
#  'Division': 'FBS',
#  'HeadCoaches': 'Ken Hatfield',
#  'Losses': 7,
#  'Notes': nan,
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.364,
#  'Wins': 4,
#  'Year': '1981-82'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': '-',
#  'Division': 'FBS',
#  'HeadCoaches': 'Ken Hatfield',
#  'Losses': 9,
#  'Notes': nan,
#  'Team': 'Air Force Falcons',
#  'Ties': 1,
#  'WL': 0.20800000000000002,
#  'Wins': 2,
#  'Year': '1980-81'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': '-',
#  'Division': 'FBS',
#  'HeadCoaches': 'Ken Hatfield',
#  'Losses': 9,
#  'Notes': nan,
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.182,
#  'Wins': 2,
#  'Year': '1979-80'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': '-',
#  'Division': nan,
#  'HeadCoaches': 'Bill Parcells',
#  'Losses': 8,
#  'Notes': nan,
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.273,
#  'Wins': 3,
#  'Year': '1978-79'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': '-',
#  'Division': 'FBS',
#  'HeadCoaches': 'Ben Martin',
#  'Losses': 8,
#  'Notes': nan,
#  'Team': 'Air Force Falcons',
#  'Ties': 1,
#  'WL': 0.22699999999999998,
#  'Wins': 2,
#  'Year': '1977-78'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': '-',
#  'Division': 'FBS',
#  'HeadCoaches': 'Ben Martin',
#  'Losses': 7,
#  'Notes': nan,
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.364,
#  'Wins': 4,
#  'Year': '1976-77'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': '-',
#  'Division': 'FBS',
#  'HeadCoaches': 'Ben Martin',
#  'Losses': 8,
#  'Notes': nan,
#  'Team': 'Air Force Falcons',
#  'Ties': 1,
#  'WL': 0.22699999999999998,
#  'Wins': 2,
#  'Year': '1975-76'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': '-',
#  'Division': 'FBS',
#  'HeadCoaches': 'Ben Martin',
#  'Losses': 9,
#  'Notes': nan,
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.182,
#  'Wins': 2,
#  'Year': '1974-75'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': '-',
#  'Division': 'FBS',
#  'HeadCoaches': 'Ben Martin',
#  'Losses': 4,
#  'Notes': nan,
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.6,
#  'Wins': 6,
#  'Year': '1973-74'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': '-',
#  'Division': 'FBS',
#  'HeadCoaches': 'Ben Martin',
#  'Losses': 4,
#  'Notes': nan,
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.6,
#  'Wins': 6,
#  'Year': '1972-73'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': '-',
#  'Division': 'FBS',
#  'HeadCoaches': 'Ben Martin',
#  'Losses': 4,
#  'Notes': nan,
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.6,
#  'Wins': 6,
#  'Year': '1971-72'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': '-',
#  'Division': 'FBS',
#  'HeadCoaches': 'Ben Martin',
#  'Losses': 3,
#  'Notes': 'Sugar Bowl',
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.75,
#  'Wins': 9,
#  'Year': '1970-71'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': '-',
#  'Division': 'FBS',
#  'HeadCoaches': 'Ben Martin',
#  'Losses': 4,
#  'Notes': nan,
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.6,
#  'Wins': 6,
#  'Year': '1969-70'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': '-',
#  'Division': 'FBS',
#  'HeadCoaches': 'Ben Martin',
#  'Losses': 3,
#  'Notes': nan,
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.7,
#  'Wins': 7,
#  'Year': '1968-69'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': '-',
#  'Division': 'FBS',
#  'HeadCoaches': 'Ben Martin',
#  'Losses': 6,
#  'Notes': nan,
#  'Team': 'Air Force Falcons',
#  'Ties': 2,
#  'WL': 0.3,
#  'Wins': 2,
#  'Year': '1967-68'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': '-',
#  'Division': 'FBS',
#  'HeadCoaches': 'Ben Martin',
#  'Losses': 6,
#  'Notes': nan,
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.4,
#  'Wins': 4,
#  'Year': '1966-67'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': '-',
#  'Division': 'FBS',
#  'HeadCoaches': 'Ben Martin',
#  'Losses': 6,
#  'Notes': nan,
#  'Team': 'Air Force Falcons',
#  'Ties': 1,
#  'WL': 0.35,
#  'Wins': 3,
#  'Year': '1965-66'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': '-',
#  'Division': 'FBS',
#  'HeadCoaches': 'Ben Martin',
#  'Losses': 5,
#  'Notes': nan,
#  'Team': 'Air Force Falcons',
#  'Ties': 1,
#  'WL': 0.45,
#  'Wins': 4,
#  'Year': '1964-65'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': '-',
#  'Division': 'FBS',
#  'HeadCoaches': 'Ben Martin',
#  'Losses': 4,
#  'Notes': 'Gator Bowl',
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.636,
#  'Wins': 7,
#  'Year': '1963-64'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': '-',
#  'Division': 'FBS',
#  'HeadCoaches': 'Ben Martin',
#  'Losses': 5,
#  'Notes': nan,
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.5,
#  'Wins': 5,
#  'Year': '1962-63'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': '-',
#  'Division': 'FBS',
#  'HeadCoaches': 'Ben Martin',
#  'Losses': 7,
#  'Notes': nan,
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.3,
#  'Wins': 3,
#  'Year': '1961-62'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': '-',
#  'Division': 'FBS',
#  'HeadCoaches': 'Ben Martin',
#  'Losses': 6,
#  'Notes': nan,
#  'Team': 'Air Force Falcons',
#  'Ties': 0,
#  'WL': 0.4,
#  'Wins': 4,
#  'Year': '1960-61'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': '-',
#  'Division': 'FBS',
#  'HeadCoaches': 'Ben Martin',
#  'Losses': 4,
#  'Notes': nan,
#  'Team': 'Air Force Falcons',
#  'Ties': 1,
#  'WL': 0.55,
#  'Wins': 5,
#  'Year': '1959-60'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': '-',
#  'Division': 'FBS',
#  'HeadCoaches': 'Ben Martin',
#  'Losses': 0,
#  'Notes': 'Tied Cotton Bowl',
#  'Team': 'Air Force Falcons',
#  'Ties': 2,
#  'WL': 0.909,
#  'Wins': 9,
#  'Year': '1958-59'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': '-',
#  'Division': 'FBS',
#  'HeadCoaches': 'Buck Shaw',
#  'Losses': 6,
#  'Notes': nan,
#  'Team': 'Air Force Falcons',
#  'Ties': 1,
#  'WL': 0.35,
#  'Wins': 3,
#  'Year': '1957-58'}
# 2017-12-11 09:35:38 [scrapy.core.scraper] DEBUG: Scraped from <200 http://stats.ncaa.org/teams/history/MFB/721>
# {'Conference': '-',
#  'Division': 'D-II',
#  'HeadCoaches': 'Buck Shaw',
#  'Losses': 2,
#  'Notes': nan,
#  'Team': 'Air Force Falcons',
#  'Ties': 1,
#  'WL': 0.722,
#  'Wins': 6,
#  'Year': '1956-57'}
# 2017-12-11 09:35:38 [scrapy.core.engine] INFO: Closing spider (finished)
# 2017-12-11 09:35:38 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 250,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 24153,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2017, 12, 11, 15, 35, 38, 546484),
#  'item_scraped_count': 62,
#  'log_count/DEBUG': 88,
#  'log_count/INFO': 7,
#  'memusage/max': 125243392,
#  'memusage/startup': 125243392,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2017, 12, 11, 15, 35, 32, 950952)}
# 2017-12-11 09:35:38 [scrapy.core.engine] INFO: Spider closed (finished)
